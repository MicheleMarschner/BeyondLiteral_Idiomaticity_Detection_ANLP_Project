# %% [markdown]
# # How to use the project in Colab

# %% [markdown]
# ## 1. Select kernel/GPU

# %% [markdown]
# ## 2. Mount Drive

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ## 3. Check if repo exists else clone

# %%
from pathlib import Path

project_path = Path("/content/drive/MyDrive/beyondliteral_idiomaticity_detection_anlp_project")     ## change this path if you want to save the project somewhere else
repo_url = "https://gitup.uni-potsdam.de/marschner5/beyondliteral_idiomaticity_detection_anlp_project.git"

if not project_path.exists():
    # !git clone {repo_url} "{project_path}"
else:
    # %cd "{project_path}"
    # !git pull

# %cd "{project_path}"

# %% [markdown]
# ## 4. Install dependencies

# %%
# !pip install -e .

# %% [markdown]
# ## 5. Set PATH variables

# %%
import os

os.environ["DATA_PREPROCESSED"] = str(project_path / "data" / "preprocessed")
os.environ["RESULTS_ROOT"]      = str(project_path / "results")
os.environ["RUNS_ROOT"]         = str(project_path / "experiments")

# %% [markdown]
# ## 6. Run entry point

# %%
# !python3 src/main.py train src/experiments/experiments_template.py --overwrite
